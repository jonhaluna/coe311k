# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import random

def approximatepi(n):
    counter = 0
    for i in range(0,n):
        pi = 4*(-1**n)/((2*n)+1)
        counter = counter + 1
    return pi
print(approximatepi(5000))
# Out:
# -0.00039996000399960006
