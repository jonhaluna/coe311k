# %% [markdown]
# Hello Python! This is my very first notebook

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(5+10)
# Out:
# 15

# %%
a = "Hello"
b = True

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# bool

# %%
number1 = (5.0/2)
number2 = (5/2)
print (number1)
print (number2)
# Out:
# 2.5
# 2.5

# %%
numIn = input("Enter a number")
# Out:
# Enter a number5

# %%
myfile = open("test.data",'w')
myfile.write(numIn)
myfile.write("HelloWorld")
myfile.write("\n")
myfile.close()

# %%
a = 2
b = 3

# %%
print(b<a or b!=a)
# Out:
# True

# %%
print(b==a)
# Out:
# False

# %%
print(b==a or b<a)
# Out:
# True

# %%
if(b>a):print("b is greater than a")

# %%
if (b>a):
    print("B is greater than A")
    else:
        print("Conditionals are awesome"))
# Out:
#   File "<ipython-input-30-0fcf6200e15d>", line 3
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
for r in range(1,3):
    print(r,r**2)
# Out:
# 1 1
# 2 4

# %%
for i in range (1,4):
    for j in range (0,5):
        print (i,j)
# Out:
# 1 0
# 1 1
# 1 2
# 1 3
# 1 4
# 2 0
# 2 1
# 2 2
# 2 3
# 2 4
# 3 0
# 3 1
# 3 2
# 3 3
# 3 4

# %%
mylist = ["Charlie", 10, "yellow", 42, "Alex", 9, "black", 21]

# %%
for t in mylist:
    print(t)
# Out:
# Charlie
# 10
# yellow
# 42
# Alex
# 9
# black
# 21

# %%
import math

def calc_hyp(a,b):
    h = math.sqrt(a*a + b*b)
    return h

# %%
my_h = calc_hyp(3,4)
print(my_h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-60fa318f0d0c> in <module>
# ----> 1 my_h = calc_hyp(3,4)
#       2 print(my_h)
#
# <ipython-input-36-44deb053408b> in calc_hyp(a, b)
#       2
#       3 def calc_hyp(a,b):
# ----> 4     h = sqrt(a*a, b*b)
#       5     return h
#
# NameError: name 'sqrt' is not defined

# %%
import math

def approximatepi(samples):
    counter = 0
    for i in range(0,samples):
        value = random.uniform(-1,1)
        x = value
        y = value
        if (x**2 + y**2 < 1):
            counter = counter + 1
    return (4*counter)/samples
